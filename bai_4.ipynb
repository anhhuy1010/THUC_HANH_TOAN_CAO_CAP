# %% [markdown]
# <a href="https://colab.research.google.com/github/anhhuy1010/THUC_HANH_TOAN_CAO_CAP/blob/main/bai_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# bài 1

# %%
import numpy as np
mienchia = np.linspace(0,2,11)
mienchia
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ])

# %% [markdown]
# bài 2

# %%
import numpy as np
import matplotlib.pyplot as plt
fs = [1,2,4]
all_time = np.linspace(0,2,200)
t = all_time[:100]
for f in fs:
  y = np.sin(2*np.pi*f*t)
  plt.plot(t, y, label='hz'.format(f))
plt.legend()
from google.colab import drive
drive.mount('/drive')
plt.savefig('/drive/My Drive/toancc/basics_python.pdf')
plt.show()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# bài 3

# %%
import numpy as np
import matplotlib.pyplot as plt
fs = [1,2,4]
all_time = np.linspace(0,2,200)
t = all_time[:100]
fig, ax = plt.subplots()
for f in fs:
  y = np.sin(2*np.pi*f*t)
  ax.plot(t, y, label='hz'.format(f))
plt.legend()
from google.colab import drive
drive.mount('/drive')
plt.savefig('/drive/My Drive/toancc/basics_python.pdf')
plt.show()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# bài 5

# %%
def thue(phan_tram): return lambda x: x*phan_tram
hcm = thue(0.012)
hcm(1000000)
# Out:
# 12000.0

# %%
def thue(phan_tram): return lambda x: x*phan_tram
hn = thue(0.01)
hn(1000000)
# Out:
# 10000.0

# %% [markdown]
# bài 6

# %%
hinhthang = lambda f, a, b: (b-a)*(f(a)+f(b))/2
from math import exp
hinhthang(exp,0,1)
1.8591409142295225
def hai_x(x):
  return 2*x
hinhthang(hai_x, 1, 2)
# Out:
# 3.0

# %% [markdown]
# bài 7

# %%
def traprule(ham, trai, phai):
  return(phai-trai)*(ham(trai)+ham(phai))/2
import math
S = 'biểu thức cần tính tích phân là e^x:'
print(S+'[a,b]')
A = float(input('nhập a:'))
B = float(input('nhập b:'))
Y = traprule(math.exp,A,B)
print(S+'[%.1E,%.1E] :'%(A,B))
print('Gía trị xấp xỉ:%.15E'%Y)
E = math.exp(B)-math.exp(A)
print('giá trị chính xác:%.15E'%E)
# Out:
# biểu thức cần tính tích phân là e^x:[a,b]
# nhập a:1
# nhập b:0
# biểu thức cần tính tích phân là e^x:[1.0E+00,0.0E+00] :
# Gía trị xấp xỉ:-1.859140914229523E+00
# giá trị chính xác:-1.718281828459045E+00

# %% [markdown]
# bài 8

# %%
import scipy
from sympy import*
import sys 
sys.displayhook = pprint
x = Symbol('x')
bt1 = integrate(x**2+x+1,x)
pprint(bt1)
bt2 = integrate(x/(x**2+2*x+1),x)
pprint(bt2)
bt3 = integrate(x**2*exp(x)*cos(x),x)
pprint(bt3) 
bt4 = integrate(exp(-x**2)*erf(x),x)
pprint(bt4)
# Out:
#  3    2
# x    x
# ── + ── + x
# 3    2
#                1
# log(x + 1) + ─────
#              x + 1
#  2  x           2  x                         x           x
# x ⋅ℯ ⋅sin(x)   x ⋅ℯ ⋅cos(x)      x          ℯ ⋅sin(x)   ℯ ⋅cos(x)
# ──────────── + ──────────── - x⋅ℯ ⋅sin(x) + ───────── - ─────────
#      2              2                           2           2
#       2
# √π⋅erf (x)
# ──────────
#     4
# None

# %% [markdown]
# bài 9

# %%
from sympy import Integral, Symbol
x = Symbol('x')
k = Symbol('k')
Integral(k*x,x)
# Out:
# Integral(k*x, x)

# %% [markdown]
# bài 10

# %%
from sympy import pprint, Integral
F = Integral(k*x,x).doit()
pprint(F)
# Out:
#    2
# k⋅x
# ────
#  2

# %% [markdown]
# bài 11

# %%
Integral(k*x, (x,0,2)).doit()
# Out:
# 2*k

# %% [markdown]
# bài 12

# %%
from sympy import Integral, Symbol
x = Symbol('x')
Integral(x,(x,2,4)).doit()
# Out:
# 6

# %% [markdown]
# bài 13

# %%
from sympy import Symbol, exp, sqrt, pi, Integral 
x = Symbol('x')
p = exp(-(x-10)**2/2)/sqrt(2*pi)
Integral(p,(x,11,12)).doit().evalf()
# Out:
# 0.135905121983278
